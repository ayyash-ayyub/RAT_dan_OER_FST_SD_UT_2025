# %%
import pandas as pd

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7474380f-4182-4102-9912-1b4b6068e281" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7474380f-4182-4102-9912-1b4b6068e281">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('latihan_penanganan_missing_data.csv')
df.head(11)
# Out:
#     id     A     B     C
# 0    1  23.0  12.0   9.0
# 1    2  45.0  12.0   8.0
# 2    3   6.0  11.0   NaN
# 3    4   NaN  23.0   6.0
# 4    5   7.0   9.0   5.0
# 5    6   8.0   NaN   3.0
# 6    7   NaN   3.0  34.0
# 7    8   8.6  26.7   NaN
# 8    9  30.3   5.4  40.6
# 9   10  19.4   2.1  47.5
# 10  11   3.8  20.6  22.6

# %%
df.isnull().sum()
# Out:
# id    0
# A     3
# B     1
# C     2
# dtype: int64

# %%
df.dropna(axis=0)
# Out:
#     id     A     B     C
# 0    1  23.0  12.0   9.0
# 1    2  45.0  12.0   8.0
# 4    5   7.0   9.0   5.0
# 8    9  30.3   5.4  40.6
# 9   10  19.4   2.1  47.5
# 10  11   3.8  20.6  22.6
# 11  12   8.6   2.1  40.6
# 12  13  19.4  48.7  47.5
# 13  14  30.3  20.6   5.8
# 15  16  30.5  48.7  25.3
# 16  17   8.6   1.3  40.6

# %%
df.dropna(thresh=4)
# Out:
#     id     A     B     C
# 0    1  23.0  12.0   9.0
# 1    2  45.0  12.0   8.0
# 4    5   7.0   9.0   5.0
# 8    9  30.3   5.4  40.6
# 9   10  19.4   2.1  47.5
# 10  11   3.8  20.6  22.6
# 11  12   8.6   2.1  40.6
# 12  13  19.4  48.7  47.5
# 13  14  30.3  20.6   5.8
# 15  16  30.5  48.7  25.3
# 16  17   8.6   1.3  40.6

# %%
df.values
# Out:
# array([[ 1. , 23. , 12. ,  9. ],
#        [ 2. , 45. , 12. ,  8. ],
#        [ 3. ,  6. , 11. ,  nan],
#        [ 4. ,  nan, 23. ,  6. ],
#        [ 5. ,  7. ,  9. ,  5. ],
#        [ 6. ,  8. ,  nan,  3. ],
#        [ 7. ,  nan,  3. , 34. ],
#        [ 8. ,  8.6, 26.7,  nan],
#        [ 9. , 30.3,  5.4, 40.6],
#        [10. , 19.4,  2.1, 47.5],
#        [11. ,  3.8, 20.6, 22.6],
#        [12. ,  8.6,  2.1, 40.6],
#        [13. , 19.4, 48.7, 47.5],
#        [14. , 30.3, 20.6,  5.8],
#        [15. ,  nan,  5.4,  5.8],
#        [16. , 30.5, 48.7, 25.3],
#        [17. ,  8.6,  1.3, 40.6]])

# %%
df.fillna(df.mean())
# Out:
#     id      A       B          C
# 0    1  23.00  12.000   9.000000
# 1    2  45.00  12.000   8.000000
# 2    3   6.00  11.000  22.753333
# 3    4  17.75  23.000   6.000000
# 4    5   7.00   9.000   5.000000
# 5    6   8.00  15.725   3.000000
# 6    7  17.75   3.000  34.000000
# 7    8   8.60  26.700  22.753333
# 8    9  30.30   5.400  40.600000
# 9   10  19.40   2.100  47.500000
# 10  11   3.80  20.600  22.600000
# 11  12   8.60   2.100  40.600000
# 12  13  19.40  48.700  47.500000
# 13  14  30.30  20.600   5.800000
# 14  15  17.75   5.400   5.800000
# 15  16  30.50  48.700  25.300000
# 16  17   8.60   1.300  40.600000

# %%
from sklearn.impute import SimpleImputer
import numpy as np

# %%
nilai_rata2 = SimpleImputer(missing_values=np.nan, strategy='mean')
nilai_rata2 = nilai_rata2.fit(df.values)
hasil = nilai_rata2.transform(df.values)
hasil
# Out:
# array([[ 1.        , 23.        , 12.        ,  9.        ],
#        [ 2.        , 45.        , 12.        ,  8.        ],
#        [ 3.        ,  6.        , 11.        , 22.75333333],
#        [ 4.        , 17.75      , 23.        ,  6.        ],
#        [ 5.        ,  7.        ,  9.        ,  5.        ],
#        [ 6.        ,  8.        , 15.725     ,  3.        ],
#        [ 7.        , 17.75      ,  3.        , 34.        ],
#        [ 8.        ,  8.6       , 26.7       , 22.75333333],
#        [ 9.        , 30.3       ,  5.4       , 40.6       ],
#        [10.        , 19.4       ,  2.1       , 47.5       ],
#        [11.        ,  3.8       , 20.6       , 22.6       ],
#        [12.        ,  8.6       ,  2.1       , 40.6       ],
#        [13.        , 19.4       , 48.7       , 47.5       ],
#        [14.        , 30.3       , 20.6       ,  5.8       ],
#        [15.        , 17.75      ,  5.4       ,  5.8       ],
# ...
